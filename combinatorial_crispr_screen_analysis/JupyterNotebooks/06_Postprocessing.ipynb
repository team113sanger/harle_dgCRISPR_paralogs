# %% [markdown]
# # Post-processing
#
# ## Table of Contents:
#
# * [0. Dependencies](#Dependencies)
# * [1. Preparing the environment](#Preparing-the-environment)
# * [2. Preparing intermediate datasets](#Collating-auxilliary-datasets)
# * [3. Identifying Bassik hits](#Identifying-Bassik-hits)

# %% [markdown]
# ***
#
# ## Dependencies
#
# Please see [INSTALL_README.md](../INSTALL_README.md) for the installation of software dependencies. This Notebook assumes that [R](https://cran.r-project.org/) and library dependencies have been installed and that the `RScript` command is available with access to the relevant data.

# %% [markdown]
# ***
#
# ## Preparing the environment

# %%
# Set the top level path for the repository
export REPO_PATH=$(dirname `pwd`)

# Show the repository path
echo "Repository path: ${REPO_PATH}"

# Check the repository path exists (don't need to check subdirectories)
if [ ! -d "${REPO_PATH}" ]; then
  echo "Top level directory path does not exist: ${REPO_PATH}"
fi
# Out:
# Repository path: /lustre/scratch124/casm/team113/users/vo1/5429_paralog_sl_vicky_finalised_for_paper

# %% [markdown]
# ***
#
# ## Preparing intermediate datasets
#
# ### DepMap relative copy number

# %%
Rscript ${REPO_PATH}/SCRIPTS/postprocessing/01_download_depmap_relative_copy_number.R \
    -d ${REPO_PATH} \
    --mapping ${REPO_PATH}/METADATA/sample_annotations.tsv \
    --annotation ${REPO_PATH}/METADATA/libraries/paralog_library.tsv

# %% [markdown]
# ### Cell model passport total copy number

# %%
Rscript ${REPO_PATH}/SCRIPTS/postprocessing/02_download_cmp_total_copy_number.R \
    -d ${REPO_PATH} \
    --mapping ${REPO_PATH}/METADATA/sample_annotations.tsv \
    --annotation ${REPO_PATH}/METADATA/libraries/paralog_library.tsv

# %% [markdown]
# ### DepMap expression

# %%
Rscript ${REPO_PATH}/SCRIPTS/postprocessing/03_download_depmap_expression.R \
    -d ${REPO_PATH} \
    --mapping ${REPO_PATH}/METADATA/sample_annotations.tsv \
    --annotation ${REPO_PATH}/METADATA/libraries/paralog_library.tsv

# %% [markdown]
# ### Common essentials

# %%
Rscript ${REPO_PATH}/SCRIPTS/postprocessing/04_download_common_essentials.R \
    -d ${REPO_PATH} \
    --annotation ${REPO_PATH}/METADATA/libraries/paralog_library.tsv

# %% [markdown]
# ### DepMap depletion probabilities

# %%
Rscript ${REPO_PATH}/SCRIPTS/postprocessing/05_download_depmap_depletion_probabilities.R \
    -d ${REPO_PATH} \
    --mapping ${REPO_PATH}/METADATA/sample_annotations.tsv \
    --annotation ${REPO_PATH}/METADATA/libraries/paralog_library.tsv

# %% [markdown]
# ### CCLE drive mutations

# %%
Rscript ${REPO_PATH}/SCRIPTS/postprocessing/06_download_ccle_mutations.R \
    -d ${REPO_PATH} \
    --mapping ${REPO_PATH}/METADATA/sample_annotations.tsv \
    --annotation ${REPO_PATH}/METADATA/libraries/paralog_library.tsv

# %% [markdown]
# ## Collate intermediate datasets

# %%
Rscript ${REPO_PATH}/SCRIPTS/postprocessing/07_combine_intermediate_datasets.R \
    -d ${REPO_PATH} \
    --mapping ${REPO_PATH}/METADATA/sample_annotations.tsv \
    --annotation ${REPO_PATH}/METADATA/libraries/paralog_library.tsv
# Out:
# System has not been booted with systemd as init system (PID 1). Can't operate.
# Failed to connect to bus: Host is down
# Reading sample annotations from: /lustre/scratch124/casm/team113/users/vo1/5429_paralog_sl_vicky_finalised_for_paper/METADATA/sample_annotations.tsv
# Reading expanded library: /lustre/scratch124/casm/team113/users/vo1/5429_paralog_sl_vicky_finalised_for_paper/METADATA/libraries/paralog_library.tsv
# Creating gene pairs x cell lines matrix...
# Adding additional library metadata...
# Adding additional sample metadata...
# Adding screened Bassik results...
# Adding screened single essentiality results...
# Adding BAGEL and DepMap common essentials...
# Adding DepMap depletion probabilities...
# Adding DepMap gene expression...
# Adding CMP copy number...
# Parsing Bassik results...
# Parsing DepMap expression...
# Parsing singles essentiality results...
# Adding CMP cancer driver mutations...
# Writing to file...
# ...

# %%
Rscript ${REPO_PATH}/SCRIPTS/postprocessing/08_build_binary_results_matrix.R \
    -d ${REPO_PATH}
# Out:
# System has not been booted with systemd as init system (PID 1). Can't operate.
# Failed to connect to bus: Host is down
# Reading combined results...
# Summarising Bassik hits...
# Summarising targetA expression...
# Summarising targetB expression...
# Averaging targetA expression...
# Averaging targetB expression...
# Summarising targetA singles depletion...
# Summarising targetB singles depletion...
# Building binary matrix...
# Writing to file...
# Combined gene level binary results TSV written to:/lustre/scratch124/casm/team113/users/vo1/5429_paralog_sl_vicky_finalised_for_paper/DATA/postprocessing/combined_gene_level_results.binary.tsv
# Combined gene level binary results RDS written to:/lustre/scratch124/casm/team113/users/vo1/5429_paralog_sl_vicky_finalised_for_paper/DATA/RDS/postprocessing/combined_gene_level_results.binary.rds
# Done.

# %% [markdown]
# ***
#
# ## Summary plots

# %%
Rscript ${REPO_PATH}/SCRIPTS/postprocessing/09_summary_plots.R \
    --dir ${REPO_PATH} \
    --bassik ${REPO_PATH}/DATA/postprocessing/combined_gene_level_results.tsv \
    --bassik_binary ${REPO_PATH}/DATA/postprocessing/combined_gene_level_results.binary.tsv \
    --mapping ${REPO_PATH}/METADATA/sample_annotations.tsv \
    --rds ${REPO_PATH}/DATA/RDS/postprocessing \
    --out ${REPO_PATH}/DATA/postprocessing
# Out:
# System has not been booted with systemd as init system (PID 1). Can't operate.
# Failed to connect to bus: Host is down
# Reading in Bassik binary matrix...
# Reading in Bassik binary matrix...
# Reading sample annotations from: /lustre/scratch124/casm/team113/users/vo1/5429_paralog_sl_vicky_finalised_for_paper/METADATA/sample_annotations.tsv
# Plotting number of Bassik hits per cell line...
# Number of Bassik hits per cell line written to: /lustre/scratch124/casm/team113/users/vo1/5429_paralog_sl_vicky_finalised_for_paper/DATA/postprocessing/number_of_bassik_hits_per_cell_line.png
# Plotting Bassik hits (number of cell lines by tumour type)...
# Stacked barplot of Bassik hits by cell line written to: /lustre/scratch124/casm/team113/users/vo1/5429_paralog_sl_vicky_finalised_for_paper/DATA/postprocessing/bassik_hits_cell_line_stacked_barplot.png
# Plotting Bassik hits by cell line (mean normalised GI)...
# ...
